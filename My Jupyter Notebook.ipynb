# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Ricardo__
#
# Beginner Data Scientist

# %% [markdown]
# *I want to use data science in the logistics industry to perform inventory prediction and optimize product storage.*

# %% [markdown]
# ### The following code calculates the square of a number

# %%
def quadrado(n):
    return n*n

quadrado(5)
# Out:
# 25

# %% [markdown]
# 1. Title
# 2. Name
# 3. Occupation
# 4. What is your interest in data science?
# 5. Explain the function below
# 6. Numbered list

# %% [markdown]
# __[www.ibm.com](http://www.ibm.com)__

# %% [markdown]
# |    Name    |   Matter  |   Result  |
# |------------|-----------|-----------|
# |John        |Biology    |Disapproved|
# |Olivia      |Math       |Approved   |
# |Sophia      |Japanese   |Disapproved|
# |Jack        |Art        |Approved   |
